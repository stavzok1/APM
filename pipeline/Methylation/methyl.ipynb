# %%
SAMPLE_DIR = "/home/stavz/masters/gdc/APM/data/Methylation/raw_samples/Tumor/"
ANNOTATION_PATH = "/home/stavz/masters/gdc/APM/annotations/Methylation/probe_reference.tsv"

# %%
# annot = pd.read_csv(ANNOTATION_PATH, sep="\t")
sample = pd.read_csv(SAMPLE_DIR + "071a05c1-f9df-4e68-b73e-8f6716d75d52.methylation_array.sesame.level3betas.txt", sep="\t", header=None)

# %%
annot = pd.read_csv(ANNOTATION_PATH, sep="\t")

# %%
genes_cds = pd.read_csv(PATHS.genes_all_features)

# %%
lncrnas_cds = pd.read_csv(PATHS.lncrnas_all_features)

# %%
lncrnas_cds["feature"].value_counts()
# Out:
# feature
# exon          26327
# transcript     7929
# gene           1635
# Name: count, dtype: int64

# %%
genes_cds["protein_coding"].value_counts()
# Out:
# transcript_type
# protein_coding                    21696
# nonsense_mediated_decay            3869
# retained_intron                    1314
# protein_coding_CDS_not_defined      573
# Name: count, dtype: int64

# %%
import pandas as pd
import sys
sys.path.insert(0, '/home/stavz/masters/gdc/APM')
sys.path[0]
from pipeline.Methylation import run_methylation_pipeline
from pipeline.config import THRESHOLDS, PATHS

# %%
run_methylation_pipeline(include_tads=False)
# Out:
# ...
# METHYLATION PIPELINE
# ...
#
# --------------------------------------------------
# STEP 1: Building probe reference
# --------------------------------------------------
# ...
# BUILDING PROBE REFERENCE TABLE
# ...
# Loading probe reference from \home\stavz\masters\gdc\APM\annotations\Methylation\probe_reference.tsv...
#   Loaded 485577 probes
#   Chromosomes: 26
#   In CGI: 306516 (63.1%)
# ...
# ANNOTATING PROBE REFERENCE
# ...
# Annotating probes with gene promoters...
#   Probes in promoters: 696 (0.14%)
# Annotating probes with gene bodies...
#   Probes in gene bodies: 1591 (0.33%)
# Annotating probes with cCREs...
#   Probes overlapping cCREs: 19878 (4.09%)
# Annotating probes with lncRNA promoters...
#   Probes in lncRNA promoters: 5882 (1.21%)
# Annotating probes with ATAC peaks...
#   Probes overlapping ATAC peaks: 26989 (5.56%)
# ...
# PROBE ANNOTATION COMPLETE
#   Total probes: 485577
#   In gene promoters: 696
#   In gene bodies: 1591
#   Overlapping cCREs: 19878
#   In lncRNA promoters: 5882
# ...

# %%
import sys, pandas as pd
print(sys.executable)
print(pd.__version__)
# Out:
# c:\Users\stavz\AppData\Local\Programs\Python\Python311\python.exe
# 2.3.3

# %%
peak_ids = pd.read_csv(PATHS.atac_peaks_mapping_csv)

# %%
peak_ids
# Out:
#                       peak_id original_name chrom     start       end
# 0      chr1:63042199-63042700     UCEC_3838  chr1  63042199  63042700
# 1      chr1:63051325-63051826     KIRC_3640  chr1  63051325  63051826
# 2      chr1:63051840-63052341     KIRC_3641  chr1  63051840  63052341
# 3      chr1:63087923-63088424      GBM_2589  chr1  63087923  63088424
# 4      chr1:63099114-63099615     SKCM_3569  chr1  63099114  63099615
# ...                       ...           ...   ...       ...       ...
# 44795    chr9:7523596-7524097    LUAD_71053  chr9   7523596   7524097
# 44796    chr9:7536303-7536804    COAD_60191  chr9   7536303   7536804
# 44797    chr9:7542712-7543213     GBM_39797  chr9   7542712   7543213
# 44798    chr9:7543413-7543914    BLCA_51253  chr9   7543413   7543914
# 44799    chr9:7549159-7549660    THCA_45568  chr9   7549159   7549660
#
# [44800 rows x 5 columns]

# %%
rppa = pd.read_csv("/home/stavz/masters/gdc/APM/annotations/RPPA/TCGA_antibodies_descriptions.gencode.v36.tsv", sep="\t")

# %%
rppa
# Out:
#           AGID peptide_target gene_name antibody_origin      source  \
# 0    AGID00100       1433BETA     YWHAB          Rabbit  Santa Cruz
# 1    AGID00111    1433EPSILON     YWHAE           Mouse  Santa Cruz
# 2    AGID00101       1433ZETA     YWHAZ          Rabbit  Santa Cruz
# 3    AGID00001          4EBP1  EIF4EBP1          Rabbit         CST
# 4    AGID00002     4EBP1_pS65  EIF4EBP1          Rabbit         CST
# ..         ...            ...       ...             ...         ...
# 482  AGID00095      YB1_pS102      YBX1          Rabbit         CST
# 483  AGID02217         YTHDF2    YTHDF2          Rabbit       Abcam
# 484  AGID02210         YTHDF3    YTHDF3          Rabbit       Abcam
# 485  AGID00326         ZAP-70     ZAP70          Rabbit         CST
# 486  AGID00432           ZEB1      ZEB1          Rabbit  Santa Cruz
#
#     catalog_number validation_status             gene_id
# 0           sc-628             Valid  ENSG00000166913.13
# ...

# %%
rppa["validation_status"].value_counts()
# Out:
# validation_status
# Valid               283
# Caution             197
# Under Evaluation      7
# Name: count, dtype: int64

# %%
rppa
# Out:
#           AGID peptide_target gene_name antibody_origin      source  \
# 0    AGID00100       1433BETA     YWHAB          Rabbit  Santa Cruz
# 1    AGID00111    1433EPSILON     YWHAE           Mouse  Santa Cruz
# 2    AGID00101       1433ZETA     YWHAZ          Rabbit  Santa Cruz
# 3    AGID00001          4EBP1  EIF4EBP1          Rabbit         CST
# 4    AGID00002     4EBP1_pS65  EIF4EBP1          Rabbit         CST
# ..         ...            ...       ...             ...         ...
# 482  AGID00095      YB1_pS102      YBX1          Rabbit         CST
# 483  AGID02217         YTHDF2    YTHDF2          Rabbit       Abcam
# 484  AGID02210         YTHDF3    YTHDF3          Rabbit       Abcam
# 485  AGID00326         ZAP-70     ZAP70          Rabbit         CST
# 486  AGID00432           ZEB1      ZEB1          Rabbit  Santa Cruz
#
#     catalog_number validation_status             gene_id
# 0           sc-628             Valid  ENSG00000166913.13
# ...
